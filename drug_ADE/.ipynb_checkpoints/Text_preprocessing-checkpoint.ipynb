# %%
import pandas as pd
import re
import ast
import numpy as np
import pandas as pd
import glob
import json

# %%
ade_terms_path
# Out:
# 'data/CTCAE_v5.0.xlsx'

# %%
def filter_metadata_df_by_title_abstract_terms(metadata_df, covid_19_term_list_path):
    """
    Filter metadata dataframe to publications containing a Covid-19 synonym in title or abstract.
    """
        
    #Concatenate title and abstract text into a single, lower-cased column
    
    metadata_df = metadata_df.fillna('')
    metadata_df.loc[:, 'title_abstract'] = metadata_df.loc[:, 'title'].str.lower() + ' ' + metadata_df.loc[:, 'abstract'].str.lower()
    metadata_df.loc[:, 'title_abstract'] = metadata_df.loc[:, 'title_abstract'].fillna('')

    #Load text file containing Covid-19 synonyms (1 per line) and generate a search pattern
    with open(covid_19_term_list_path) as f:
        covid_19_terms = f.read().splitlines()
        covid_19_term_pattern = '|'.join([i.lower() for i in covid_19_terms])

    covid19_df = metadata_df.loc[metadata_df.title_abstract.str.contains(covid_19_term_pattern)]
    
    return covid19_df

def filter_metadata_df_by_publ_date_cutoff(metadata_df, pub_date_cutoff):
    
    date_filtered_df = metadata_df.loc[metadata_df['publish_time'] > pub_date_cutoff]

    return date_filtered_df

# %%
#Main

#Load metadata.csv as dataframe and filter to 
metadata_df = pd.read_csv(metadata_csv_path)
covid19_df = filter_metadata_df_by_title_abstract_terms(metadata_df, covid_19_term_list_path)

#Filter covid19_df by publication date cutoff
covid19_date_filtered_df = filter_metadata_df_by_publ_date_cutoff(covid19_df, pub_date_cutoff)

covid19_date_filtered_df.to_csv('data/covid19_date_filt_metadata_200504.csv')
# Out:
# /home/aradhana/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
covid19_date_filtered_df.head()
# Out:
#        cord_uid                                       sha source_x  \
# 11763  ene62kcz  26f8c5fbd310c95c2e1fb04c34ed6f5d10901d07      PMC
# 11766  uw41ygmc  cf12680358351109a975a23165bbb48620b578a5      PMC
# 11851  4vgnzvag  8bb39b846b0bd9548526bad9e74fed1e4a8ac4cb      PMC
# 11861  7unnfmks  058f046fec5eee31c9ed0bdacd37aa22ba485993      PMC
# 11873  8opynjru  a0839bf8f94d79c1253bf89f170c22f9342fc095      PMC
#
#                                                    title  \
# 11763  Evaluating the potential impact of targeted va...
# 11766  Development of a recombinant replication-defic...
# 11851  Molecular epidemiology of respiratory viruses ...
# 11861  Clinical outcomes among hospital patients with...
# 11873  Middle East Respiratory Syndrome Coronavirus, ...
#
#                                 doi       pmcid    pubmed_id license  \
# 11763     10.1186/s12976-019-0112-6  PMC6778978  3.15877e+07   cc-by
# 11766  10.1371/journal.pone.0223684  PMC6779238  3.15897e+07   cc-by
# 11851     10.1186/s12917-019-2103-6  PMC6802313   3.1639e+07   cc-by
# 11861     10.1186/s12879-019-4555-5  PMC6805532  3.16406e+07   cc-by
# 11873        10.3201/eid2511.190726  PMC6810214  3.14302e+07   no-cc
#
#                                                 abstract publish_time  \
# 11763  BACKGROUND: Severe Acute Respiratory Syndrome ...   2019-10-07
# 11766  Middle East respiratory syndrome-coronavirus (...   2019-10-07
# 11851  BACKGROUND: Viral diseases are a matter of gre...   2019-10-21
# 11861  BACKGROUND: Mortality is high among patients w...   2019-10-22
# 11873  We characterized exposures and demographics of...   2019-11-01
#
#                                                  authors  \
# 11763  Abdirizak, Fatima; Lewis, Rayleen; Chowell, Ge...
# 11766  Kato, Hirofumi; Takayama-Ito, Mutsuyo; Iizuka-...
# 11851  Umar, Sajid; Teillaud, Angélique; Aslam, Hassa...
# 11861  Habib, Abdulrahman Mohammed G.; Ali, Mohamed A...
# 11873  Hakawi, Ahmed; Rose, Erica Billig; Biggs, Holl...
#
#                     journal Microsoft Academic Paper ID WHO #Covidence  \
# 11763  Theor Biol Med Model
# 11766              PLoS One
# 11851           BMC Vet Res
# 11861        BMC Infect Dis
# 11873      Emerg Infect Dis
#
#       arxiv_id  has_pdf_parse  has_pmc_xml_parse   full_text_file  \
# 11763                    True               True  comm_use_subset
# 11766                    True               True  comm_use_subset
# 11851                    True               True  comm_use_subset
# 11861                    True               True  comm_use_subset
# 11873                    True               True   custom_license
#
#                                                      url  \
# 11763  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 11766  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 11851  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 11861  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 11873  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                           title_abstract
# 11763  evaluating the potential impact of targeted va...
# 11766  development of a recombinant replication-defic...
# 11851  molecular epidemiology of respiratory viruses ...
# 11861  clinical outcomes among hospital patients with...
# 11873  middle east respiratory syndrome coronavirus, ...

# %%
def truncate_pq_text_file(pq_text_file, pq_text_files_cols_oi, uid_list):
    """
    Load text file as dataframe, filter to relevant columns (cord_uid, sentence_id, section, sentence) and 
    cord_uids for Covid-19 papers.    
    
    Return truncated dataframe.
    
    """
    print("Loading dataframe from %s" % pq_text_file)
    text_file_df = pd.read_parquet(pq_text_file)
    text_file_trunc_df = text_file_df[pq_text_files_cols_oi]
    text_file_trunc_df = text_file_trunc_df.loc[text_file_trunc_df.cord_uid.isin(uid_list)]
    
    return text_file_trunc_df
    
def truncate_pq_text_files(pq_text_file_dir, pq_text_files_cols_oi, csv_trunc_text_file_dir, uid_list):
    """
    For each full text parquet file in pq_text_file_dir, load as dataframe, 
    filter to specified cord_uids and columns of interest, and write to csv file in csv_trunc_text_file_dir
    """
    
    print("Parquet text files input directory: %s" % pq_text_file_dir)
    pq_text_files = glob.glob('%s*' % pq_text_file_dir)
    print("Files in text files input directory: %d" % len(pq_text_files))

    print("Parquet text files output directory: %s" % csv_trunc_text_file_dir)
    print('\n')

    for pq_text_file in pq_text_files:
        
        text_file_trunc_df = truncate_pq_text_file(pq_text_file, pq_text_files_cols_oi, uid_list)
        text_file_name = pq_text_file.split('.')[0].split('/')[-1]
        outfile = '%s%s_trunc.csv' %(csv_trunc_text_file_dir, text_file_name)
    
        print("Writing truncated text dataframe to %s" % outfile)
        text_file_trunc_df.to_csv(outfile)

# %%
def concat_dataframes_from_dir_csvs(trunc_csv_dir):

    trunc_csv_files = glob.glob('%s*' % trunc_csv_dir)
    print("Files in truncated csv output directory: %d" % len(trunc_csv_files))

    trunc_dfs = []
    for trunc_csv_file in trunc_csv_files:
        trunc_dfs.append(pd.read_csv(trunc_csv_file, index_col=0))
    
    merged_trunc_df = pd.concat(trunc_dfs)
    return merged_trunc_df

# %%
#Main

print("Step 1: Filtering metadata csv by Covid-19 synoynms and publication date...")

#covid19_df = pd.read_csv(metadata_csv_path)
uid_list = covid19_date_filtered_df.cord_uid.tolist()

print("Step 2: Loading full text dataframes, filtering to extracted uids, and writing to csv files...")
truncate_pq_text_files(pq_text_file_dir, pq_text_files_cols_oi, csv_trunc_text_file_dir, uid_list)    
print('\n')
# Out:
# Step 1: Filtering metadata csv by Covid-19 synoynms and publication date...
# Step 2: Loading full text dataframes, filtering to extracted uids, and writing to csv files...
# Parquet text files input directory: data/v8_data_P/
# Files in text files input directory: 20
# Parquet text files output directory: data/output/v8_truncated_text_files/
#
#
# Loading dataframe from data/v8_data_P/v8processedText3.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText3_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText10.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText10_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText18.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText18_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText4.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText4_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText13.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText13_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText17.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText17_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText5.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText5_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText9.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText9_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText7.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText7_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText14.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText14_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText6.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText6_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText16.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText16_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText12.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText12_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText19.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText19_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText1.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText1_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText2.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText2_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText0.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText0_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText8.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText8_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText11.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText11_trunc.csv
# Loading dataframe from data/v8_data_P/v8processedText15.parquet
# Writing truncated text dataframe to data/output/v8_truncated_text_files/v8processedText15_trunc.csv

# %%
print("Step 3: Merging truncated text dataframes and extracting sentence ids...")
concat_text_trunc_df = concat_dataframes_from_dir_csvs(csv_trunc_text_file_dir)
text_sentence_ids = concat_text_trunc_df.sentence_id.tolist()
print("Number of sentence ids: %d" % len(text_sentence_ids))
print("Number of unique sentence ids: %d" % len(set(text_sentence_ids)))
print('\n')
# Out:
# Step 3: Merging truncated text dataframes and extracting sentence ids...
# Files in truncated csv output directory: 20
# Number of sentence ids: 336314
# Number of unique sentence ids: 336314

# %%
#find out drug names
# Out:
# 'data/DrugNames.txt'

# %%
"""
Read drug terms from reference file and generate regex pattern for matching.
"""

with open(drug_terms_path) as f:
    drug_terms = ['%s' % i.lower() for i in f.read().splitlines()]
    
drug_terms_pattern =  '\W' + '\W|\W'.join(drug_terms) + '\W'

# %%
"""
Filter to rows where section text contains drug term regex pattern.
"""
print(concat_text_trunc_df[concat_text_trunc_df.isnull().any(axis=1)])
concat_text_trunc_df=concat_text_trunc_df.dropna()
contain_drug_mask = concat_text_trunc_df['sentence'].str.contains(drug_terms_pattern, case=False)
#section_text_with_drugs_df = concat_text_trunc_df[contain_drug_mask]
# Out:
# Empty DataFrame
# Columns: [cord_uid, sentence_id, section, sentence]
# Index: []
# /home/aradhana/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
section_text_with_drugs_df = concat_text_trunc_df[contain_drug_mask]

# %%
#covid19_date_filtered_df['cord_uid'=='m201s56m']
covid19_date_filtered_df[covid19_date_filtered_df['cord_uid'].str.contains('m201s56m')]
# Out:
#        cord_uid                                                sha  source_x  \
# 45394  m201s56m  4ecc308121e248cad3f81a899c0e2df3a4484421; 622d...  Elsevier
#
#                                                    title  \
# 45394  A UK-wide British Society of Thoracic Imaging ...
#
#                               doi       pmcid pubmed_id    license abstract  \
# 45394  10.1016/j.crad.2020.03.005  PMC7138155            els-covid
#
#       publish_time                                            authors  \
# 45394   2020-05-31  Hare, S.S.; Rodrigues, J.C.L.; Jacob, J.; Edey...
#
#                   journal Microsoft Academic Paper ID WHO #Covidence arxiv_id  \
# 45394  Clinical Radiology
#
#        has_pdf_parse  has_pmc_xml_parse  full_text_file  \
# 45394           True              False  custom_license
#
#                                               url  \
# 45394  https://doi.org/10.1016/j.crad.2020.03.005
#
#                                           title_abstract
# 45394  a uk-wide british society of thoracic imaging ...

# %%
section_text_with_drugs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12710 entries, 16996 to 760
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cord_uid     12710 non-null  object
#  1   sentence_id  12710 non-null  object
#  2   section      12710 non-null  object
#  3   sentence     12710 non-null  object
# dtypes: object(4)
# memory usage: 496.5+ KB

# %%
section_text_with_drugs_df.to_csv("data/output/drug_mentions.csv")

# %%
# """
# Manual annotation of drug terms used.

# """

section_text_with_drugs_ann_df = section_text_with_drugs_df.copy()

section_text_with_drugs_ann_df['drug_terms_used'] = ''
section_text_with_drugs_ann_df['drug_count'] = 0
for index, row in section_text_with_drugs_ann_df.iterrows():
    
    drugs_used = []
    count=0
    for drug in drug_terms:
        if drug in row.sentence:
            drugs_used.append(drug)
            count+=1
    section_text_with_drugs_ann_df.at[index, 'drug_terms_used'] = ','.join(drugs_used)
    section_text_with_drugs_ann_df.at[index, 'drug_count'] = count
section_text_with_drugs_ann_df.to_csv('data/output/section_texts_with_drug_mentions_ann_200504.csv')

# %%
section_text_with_drugs_ann_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12710 entries, 16996 to 760
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cord_uid         12710 non-null  object
#  1   sentence_id      12710 non-null  object
#  2   section          12710 non-null  object
#  3   sentence         12710 non-null  object
#  4   drug_terms_used  12710 non-null  object
#  5   drug_count       12710 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 1015.1+ KB

# %%
"Read ADE file and prepare list"
ade=pd.read_excel(ade_terms_path)
ade_list=ade['CTCAE Term'].values.tolist()

# %%
#Now,Its time to find adverse drug event mentioned in small subset which contains drug

#section_text_with_drugs_ann_df = concat_text_trunc_df.copy()

section_text_with_drugs_ann_df['ade_terms_used'] = ''
section_text_with_drugs_ann_df['ade_count'] = 0
for index, row in section_text_with_drugs_ann_df.iterrows():
    
    ade_used = []
    count=0
    for ad_event in ade_list:
        if ad_event in row.sentence:
            ade_used.append(ad_event)
            count+=1
    section_text_with_drugs_ann_df.at[index, 'ade_terms_used'] = ','.join(ade_used)
    section_text_with_drugs_ann_df.at[index, 'ade_count'] = count

# %%
section_text_with_drugs_ann_df.head()
# Out:
#        cord_uid      sentence_id  \
# 16996  xhaltyff  xhaltyff1816996
# 27196  kaip0d1i   kaip0d1i627196
# 34241  8xx1xm2d   8xx1xm2d034241
# 34243  8xx1xm2d   8xx1xm2d034243
# 34247  8xx1xm2d   8xx1xm2d034247
#
#                                                  section  \
# 16996  Concept 2-obstacles and opportunities in pre-c...
# 27196                             Support vector machine
# 34241                                          body_text
# 34243                                          body_text
# 34247                                          body_text
#
#                                                 sentence     drug_terms_used  \
# 16996  The point was reiterated that we need to stren...               align
# 27196  SVM with a radial kernel is used to perform th...             perform
# 34241  In this Journal, Zhu et al. recently reported ...  colistin,ella,ting
# 34243  2 Oral non-absorbed colistin has been proposed...            colistin
# 34247  Here, we studied the impact of non-absorbed or...            colistin
#
#        drug_count ade_terms_used  ade_count
# 16996           1                         0
# 27196           1                         0
# 34241           3                         0
# 34243           1                         0
# 34247           1                         0

# %%
section_text_with_drugs_ann_df.to_csv("data/output/drug_ade_dataset.csv")

# %%
"""filter out sentences where one drug ,one ADE event is mentioned
"""
one_drug_ade_df=section_text_with_drugs_ann_df[(section_text_with_drugs_ann_df['drug_count']==1) & (section_text_with_drugs_ann_df['ade_count']==1)]

# %%
one_drug_ade_df
# Out:
#        cord_uid      sentence_id  \
# 24537  hl6mqd9j   hl6mqd9j024537
# 21826  1mjaycee   1mjaycee921826
# 29356  82jdp391   82jdp391029356
# 12263  ti9b1etu   ti9b1etu912263
# 2773   zblitbo0    zblitbo052773
# 15034  skknfc6h  skknfc6h1015034
# 4970   lmjaldcs   lmjaldcs644970
# 2863   di7hfghi    di7hfghi62863
# 21826  i1q3n101  i1q3n1012321826
# 4970   pzjxsh02   pzjxsh02154970
#
#                                                  section  \
# 24537                                          body_text
# 21826  Potential therapeutic strategies against COVID-19
# 29356                                       Introduction
# 12263                                         Procedures
# 2773                                Statistical Analysis
# 15034                           Definition of conditions
# 4970                                        Shortcomings
# 2863                                            Outcomes
# 21826                                         Discussion
# 4970                                    Workforce safety
#
#                                                 sentence drug_terms_used  \
# 24537  Hypoxia as an often seen problem is frequently...         glucose
# 21826  Nafamostat, Nitazoxanide, Ribavirin, Penciclov...       melatonin
# 29356  4 Fever, alcohol, and medications causing sodi...         alcohol
# 12263  Acute kidney injury was identified by an abrup...      creatinine
# 2773   Chronic kidney diseases and elevated serum cre...      creatinine
# 15034  Acute kidney injury (AKI) was classified on th...      creatinine
# 4970   We believe that atmospheric pressure, temperat...             air
# 2863   6 Acute kidney injury was identified on the ba...      creatinine
# 21826  Anxiety may lead to increased cortisol levels,...       melatonin
# 4970   Coughing can generate large droplets that fall...             air
#
#        drug_count          ade_terms_used  ade_count
# 24537           1                 Hypoxia          1
# 21826           1                 Anxiety          1
# 29356           1                   Fever          1
# 12263           1     Acute kidney injury          1
# 2773            1  Chronic kidney disease          1
# 15034           1     Acute kidney injury          1
# 4970            1                   Cough          1
# 2863            1     Acute kidney injury          1
# 21826           1                 Anxiety          1
# 4970            1                   Cough          1

# %%
"""filter out sentences where more than one drug ,more than one ADE event is mentioned
"""
gt_one_drug_ade_df=section_text_with_drugs_ann_df[(section_text_with_drugs_ann_df['drug_count']>1) & (section_text_with_drugs_ann_df['ade_count']>1)]

# %%
gt_one_drug_ade_df
# Out:
# Empty DataFrame
# Columns: [cord_uid, sentence_id, section, sentence, drug_terms_used, drug_count, ade_terms_used, ade_count]
# Index: []

# %%
#we dont have any data with more than 1 ade mentioned,need to check more ADE event terms

# %%
"""filter out sentences where more than one drug ,more than one ADE event is mentioned
"""
gt_one_drug_one_ade_df=section_text_with_drugs_ann_df[(section_text_with_drugs_ann_df['drug_count']>1) & (section_text_with_drugs_ann_df['ade_count']>=1)]
gt_one_drug_one_ade_df
# Out:
#        cord_uid      sentence_id  \
# 8602   sfcvrun7    sfcvrun778602
# 14223  myh73pe6  myh73pe64614223
# 5787   ts2tsua7    ts2tsua795787
# 28978  71n7fxo9   71n7fxo9828978
# 28792  7y1uoj8l   7y1uoj8l328792
# 32090  t8azymo7  t8azymo72632090
# 3102   yy7abob9   yy7abob9303102
# 19137  cpu3q9o6   cpu3q9o6019137
#
#                                                 section  \
# 8602                Miocarditis fulminante por COVID-19
# 14223  On ACE2 expression and exploring drug candidates
# 5787                    Data collection and definitions
# 28978                 Severe Acute Respiratory Syndrome
# 28792                    Evaluation of clinical results
# 32090                   Antiviral therapy ::: Treatment
# 3102               Laboratory and radiographic findings
# 19137                                         body_text
#
#                                                 sentence  \
# 8602   Myocarditis treatment was started with immunog...
# 14223  This drug has been approved for treating Immun...
# 5787   Acute kidney injury (AKI) was identified and c...
# 28978  Coughing or sneezing by an infected individual...
# 28792  PSI: age (direct scoring, such as 50 years old...
# 32090  Diarrhea, nausea, vomiting, liver damage, and ...
# 3102   Anemia, lymphopenia, hypoxemia, abnormal kidne...
# 19137  Retinopathy is a dose-limiting adverse effect ...
#
#                                          drug_terms_used  drug_count  \
# 8602   lopinavir,methylprednisolone,prednisolone,rito...           5
# 14223                                rosin,ting,tyrosine           3
# 5787                                       creatinine,nf           2
# 28978                                 air,bran,nf,propel           4
# 28792                                       glucose,urea           2
# 32090                     lopinavir,react,ritonavir,ting           4
# 3102                                    creatine,lactate           2
# 19137       chloroquine,hydroxychloroquine,pea,pear,ting           5
#
#             ade_terms_used  ade_count
# 8602           Myocarditis          1
# 14223              Purpura          1
# 5787   Acute kidney injury          1
# 28978                Cough          1
# 28792     Pleural effusion          1
# 32090             Diarrhea          1
# 3102                Anemia          1
# 19137          Retinopathy          1

# %%
"""filter out sentences where  one drug ,more than one ADE event is mentioned
"""
one_drug_gt_ade_df=section_text_with_drugs_ann_df[(section_text_with_drugs_ann_df['drug_count']==1) & (section_text_with_drugs_ann_df['ade_count']>1)]
one_drug_gt_ade_df
# Out:
# Empty DataFrame
# Columns: [cord_uid, sentence_id, section, sentence, drug_terms_used, drug_count, ade_terms_used, ade_count]
# Index: []
