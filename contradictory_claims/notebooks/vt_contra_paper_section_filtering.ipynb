# %%
"""
Using a spaCy EntityRuler pipeline component to identify entities (virus terms, drug terms, etc.) in text passages.

Edit - Not sure if this is the direction we're going, so just used regex and pandas to filter the section texts for now.
"""
# Out:
# "\nUsing a spaCy EntityRuler pipeline component to identify entities (virus terms, drug terms, etc.) in text passages.\n\nEdit - Not sure if this is the direction we're going, so just used regex and pandas to filter the section texts for now.\n"

# %%
import json
import spacy
import en_core_sci_lg
from spacy.pipeline import EntityRuler
import re
import pandas as pd

# %%
"""
Input
"""

input_path = '../../../../resources/'
ent_ruler_jsonl_path = '%sspacy_entity_rulers/vt_task_entity_ruler_200501.jsonl' % input_path
merged_text_vec_csv_path = '%scord_titles_abstracts_conclusions.csv' % input_path
drug_terms_path = '%sspacy_entity_rulers/input/DrugNames.txt' % input_path

"""
Output
"""

output_path = '../../../../output/'

section_text_with_drugs_outpath = '%ssection_text_with_drug_mentions_200504.csv' % output_path
section_text_with_drugs_ann_outpath = '%ssection_texts_with_drug_mentions_ann_200507.csv' % output_path
section_sent_text_with_drugs_ann_outpath = '%ssection_texts_with_drug_mentions_ann_200504.csv' % output_path

# %%
nlp = en_core_sci_lg.load()

merged_text_vec_df = pd.read_csv(merged_text_vec_csv_path, index_col=0)

# %%
disabled = nlp.disable_pipes("tagger", "parser", "ner")
entity_ruler = EntityRuler(nlp)
entity_ruler.from_disk(ent_ruler_jsonl_path)
disabled.restore()

nlp.add_pipe(entity_ruler, before='ner')
nlp.remove_pipe('ner')
# Out:
# ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x7f87a8de2ac0>)

# %%
def annotate_text_with_named_entities(text):
    """
    Using an EntityRuler component, identify named entities and merge their component tokens.
    :param passage (str): a text passage.
    :return (Spacy.doc): a doc object that includes the identified named entities.
    """

    doc = nlp(text.lower())
    with doc.retokenize() as retokenizer:
        for ent in doc.ents:
            retokenizer.merge(ent)

    return doc

# %%
"""
Merge all sentences belonging to each section of each paper into contiguous text passages.
"""

concat_sent_df = merged_text_vec_df.groupby(['cord_uid', 'section'], as_index=False).agg({'sentence': ' '.join})
concat_sent_df.loc[:, 'sentence'] = concat_sent_df.loc[:, 'sentence'].str.lower()

concat_sent_df= concat_sent_df.rename(columns={'sentence' :'text'})

#Adding a space before and after each text to allow regex matches at start and end of text.
concat_sent_df['text_spaced'] = ' ' + concat_sent_df.loc[:, 'text'] + ' '

# %%
"""
Read drug terms from reference file and generate regex pattern for matching.
"""

with open(drug_terms_path) as f:
    drug_terms = ['%s' % i.lower() for i in f.read().splitlines()]
    
drug_terms_pattern =  '\W' + '\W|\W'.join(drug_terms) + '\W'

drug_terms_pattern = drug_terms_pattern.replace('.', '\.')

# %%
"""
Filter to rows where section text contains drug term regex pattern.
"""

contain_drug_mask = concat_sent_df['text_spaced'].str.contains(drug_terms_pattern, case=False)
section_text_with_drugs_df = concat_sent_df[contain_drug_mask]

# %%
contain_drug_mask.value_counts()
# Out:
# False    9169
# True      800
# Name: text_spaced, dtype: int64

# %%
"""
Manual annotation of drug terms used.

"""

section_text_with_drugs_ann_df = section_text_with_drugs_df.copy()

section_text_with_drugs_ann_df['drug_terms_used'] = ''

for index, row in section_text_with_drugs_ann_df.iterrows():
    
    drugs_used = []
    for drug in drug_terms:
        if drug in row.text:
            drugs_used.append(drug)
    
    section_text_with_drugs_ann_df.at[index, 'drug_terms_used'] = ','.join(drugs_used)

# %%
"""
Writing section texts to outfile.

"""

section_text_with_drugs_ann_df = section_text_with_drugs_ann_df.drop(columns=['text'])
section_text_with_drugs_ann_df.to_csv(section_text_with_drugs_ann_outpath)

# %%
#section_text_with_drugs_ann_df = pd.read_csv(section_text_with_drugs_ann_outpath, index_col=0)
section_sent_text_with_drugs_ann_outpath
# Out:
# '../../../../output/section_texts_with_drug_mentions_ann_200504.csv'

# %%
section_sent_texts_with_drugs_df = pd.merge(merged_text_vec_df, section_text_with_drugs_ann_df, how='inner', left_on=['cord_uid', 'section'], right_on=['cord_uid', 'section'])

section_sent_texts_with_drugs_df = section_sent_texts_with_drugs_df.drop(columns=['text_spaced'])

section_sent_texts_with_drugs_df.to_csv(section_sent_text_with_drugs_ann_outpath)

# %%
#Verify that final cord_uid : sections included matches section_text_with_drugs_ann_df
section_sent_cord_uid_section_dict = section_sent_texts_with_drugs_df.groupby('cord_uid')['section'].apply(set).to_dict()

section_passage_cord_uid_section_dict = section_text_with_drugs_ann_df.groupby('cord_uid')['section'].apply(set).to_dict()

print(section_passage_cord_uid_section_dict == section_sent_cord_uid_section_dict)
# Out:
# True

# %%
prior_section_sent_texts_with_drugs_df = pd.read_csv('../../../../output/section_sent_texts_with_drug_mentions_ann_200502.csv')

# %%
#Comparing prior and current outputs manually

test_df = section_sent_texts_with_drugs_df.merge(prior_section_sent_texts_with_drugs_df, how='outer', indicator=True).loc[lambda x : x['_merge'] == 'left_only']
#test_df = prior_section_sent_texts_with_drugs_df.merge(section_sent_texts_with_drugs_df, how='outer', indicator=True).loc[lambda x : x['_merge'] == 'left_only']
test_df.sentence.tolist()
# Out:
# ['TH17 responses in cytokine storm of COVID-19: An emerging target of JAK2 inhibitor Fedratinib',
#  'Nelfinavir was predicted to be a potential inhibitor of 2019-nCov main protease by an integrative approach combining homology modelling, molecular docking and binding free energy calculation',
#  'Favorable changes of CT findings in a patient with COVID-19 pneumonia after treatment with tocilizumab',
#  'Lactate dehydrogenase, a Risk Factor of Severe COVID-19 Patients',
#  'Hydrogen Peroxide Vapor sterilization of N95 respirators for reuse',
#  'Angiotensin II Receptor Blockers and Angiotensin-Converting Enzyme Inhibitors Usage is Associated with Improved Inflammatory Status and Clinical Outcomes in COVID-19 Patients With Hypertension',
#  'Remdesivir inhibits renal fibrosis in obstructed kidneys',
#  'Atazanavir inhibits SARS-CoV-2 replication and pro-inflammatory cytokine production',
#  'Amantadine disrupts lysosomal gene expression; potential therapy for COVID19',
#  'Nelfinavir inhibits replication of severe acute respiratory syndrome coronavirus 2 in vitro.',
#  'Chloroquine diphosphate in two different dosages as adjunctive therapy of hospitalized patients with severe respiratory syndrome in the context of coronavirus (SARS-CoV-2) infection: Preliminary safety results of a randomized, double-blinded, phase IIb clinical trial (CloroCovid-19 Study)',
#  'Convalescent Plasma to Treat COVID-19: Chinese Strategy and Experiences',
#  'Tocilizumab treatment in severe COVID-19 patients attenuates the inflammatory storm incited by monocyte centric immune interactions revealed by single-cell analysis',
#  'Structural Basis for the Inhibition of the RNA-Dependent RNA Polymerase from SARS-CoV-2 by Remdesivir',
#  'Convalescent plasma as a potential therapy for COVID-19',
#  'Remdesivir as a possible therapeutic option for the COVID-19',
#  'Arbidol combined with LPV/r versus LPV/r alone against Corona Virus Disease 2019:',
#  'A retrospective cohort study',
#  'Metronidazole; a Potential Novel Addition to the COVID-19 Treatment Regimen',
#  'Convalescent plasma: A possible treatment of COVID-19 in India',
#  'Tocilizumab, an anti-IL6 receptor antibody, to treat Covid-19-related respiratory failure: a case report',
#  'BARICITINIB - A JANUASE KINASE INHIBITOR - NOT AN IDEAL OPTION FOR MANAGEMENT OF COVID 19',
#  'Chloroquine as prophylactic agent against COVID-19?',
#  'Hydroxychloroquine is being used globally for treatment and prophylaxis of COVID-19.',
#  'Various countries have issued recommendations on its use based on in-vitro, or small clinical studies.',
#  'In absence of randomized trial data, these recommendations reflect the extraordinary situation of a rapidly evolving pandemic of a highly contagious disease.',
#  'The guidelines are likely to change as more data from randomized clinical trials is available.',
#  'The decision to use HCQ for COVID-19 should take into account the occasional possibility of cardiac arrhythmia.',
#  'Indian Heart Rhythm Society recommends the use of HCQ as per the ICMR task force recommendations and strongly discourages its use for the general public without medical supervision and prescription.',
#  'Even though a 12-lead ECG is a widely available tool, obtaining ECG of every suspected or confirmed patient of COVID-19 may be impractical and strain healthcare resources in a pandemic situation.',
#  'Hence, using smartphone-based pocket ECG devices can potentially save healthcare resources in the current situation.',
#  'The measures of restrained advocacy for potentially beneficial effects of HCQ and advice against self-medication can help prevent adverse events related to this drug.',
#  'Baricitinib for COVID-19: a suitable treatment?',
#  "– Authors' reply",
#  'Remdesivir for severe acute respiratory syndrome coronavirus 2 causing COVID-19: An evaluation of the evidence',
#  'Cannabidiol as prophylaxis for SARS-CoV-2 and COVID-19?',
#  'Unfounded claims versus potential risks of medications during the pandemic',
#  'Baricitinib for COVID-19: a suitable treatment?',
#  'Indomethacin has a potent antiviral activity against SARS CoV-2 in vitro and canine coronavirus in vivo',
#  'Baricitinib as potential treatment for 2019-nCoV acute respiratory disease',
#  'Hydroxychloroquine in patients with COVID-19: an open-label, randomized, controlled trial',
#  'Remdesivir and SARS-CoV-2: structural requirements at both nsp12 RdRp and nsp14 Exonuclease active-sites',
#  'Adalimumab for Treatment of Hidradenitis Suppurativa During the COVID-19 Pandemic: Safety Considerations',
#  'A Case of Coronavirus Disease 2019 Treated With Ciclesonide',
#  'Chloroquine for the 2019 novel coronavirus SARS-CoV-2']

# %%
"""
Manual spot-checking.

"""

merged_text_cord_uids = set(merged_text_vec_df.cord_uid.tolist())

section_text_cord_uids = set(section_text_with_drugs_ann_df.cord_uid.tolist())

cord_uid_section_tuples = list(zip(section_text_with_drugs_ann_df.cord_uid.tolist(), section_text_with_drugs_ann_df.section.tolist()))
cord_uid_section_tuples
# Out:
# [('02q9y011', 'RESULTS AND DISCUSSION'),
#  ('08vsaov7', 'DISCUSSION'),
#  ('0a49okho', 'Discussion'),
#  ('0d77ojnb', 'Discussion and Conclusion'),
#  ('0d77ojnb', 'abstract'),
#  ('0d77ojnb', 'title'),
#  ('0euaaspo',
#   'Complications, treatment and clinical outcomes during hospitalization and follow-up 296'),
#  ('0gier0lu', 'abstract'),
#  ('0hrmk77p', 'Conclusion'),
#  ('0hrmk77p', 'Discussion'),
#  ('0lk8eujq', 'Discussion'),
#  ('0lk8eujq', 'abstract'),
#  ('0lk8eujq', 'title'),
#  ('0nhgxoim', 'Added value of this study'),
#  ('0nhgxoim', 'Discussion'),
#  ('0rk2dw4e', 'DISCUSSION'),
#  ('0uengr9t', 'Conclusion'),
#  ('0uengr9t', 'abstract'),
#  ('0uengr9t', 'title'),
#  ('11060ijh',
#   'Docking Results of Compounds in Garlic Essential Oil into the PDB6LU7 Protein of SARS-CoV-2 ::: Docking Simulation ::: Results and Discussion'),
#  ('11060ijh', 'abstract'),
#  ('125o0o7x',
#   'Prediction of the clinical outcome of COVID-19 patients using T lymphocyte subsets with 340 cases from Wuhan, China: a retrospective cohort study and a web visualization tool'),
#  ('13dsznnt', 'Discussion'),
#  ('13jupb26', 'abstract'),
#  ('14he8n3u', 'Conclusions'),
#  ('14he8n3u', 'Discussion'),
#  ('14he8n3u', 'abstract'),
#  ('14he8n3u', 'title'),
#  ('161zm74f', 'Results and Discussion'),
#  ('161zm74f', 'abstract'),
#  ('16ff3c7m', 'abstract'),
#  ('16ff3c7m', 'title'),
#  ('1esupl4q', 'abstract'),
#  ('1kkpx108', 'Abstract'),
#  ('1mjaycee', 'Conclusion and perspective'),
#  ('1mmqfp7g', 'abstract'),
#  ('1n96pz86', 'Discussion'),
#  ('1s2zsqoq', 'abstract'),
#  ('23mp5961', 'Discussion'),
#  ('23mp5961', 'abstract'),
#  ('289fu2yb', 'abstract'),
#  ('2fx7a0ta', 'abstract'),
#  ('2hbcbvt6', 'DISCUSSION'),
#  ('2hbcbvt6', 'Outcome Data'),
#  ('2hbcbvt6', 'abstract'),
#  ('2hbcbvt6', 'title'),
#  ('2kkw9nwa', 'Conclusion.'),
#  ('2kkw9nwa', 'Discussion.'),
#  ('2kkw9nwa', 'abstract'),
#  ('2rhhw3sx', 'title'),
#  ('2s5xd1oc', 'Research in context Evidence before this study'),
#  ('2tu707ng', 'abstract'),
#  ('2u6ki9dv', 'Discussion'),
#  ('2uvibr2j', 'abstract'),
#  ('2vdvswda', 'abstract'),
#  ('2x7l1s75', 'AGI grades and clinical outcomes'),
#  ('30x26ip7', 'abstract'),
#  ('30x26ip7', 'title'),
#  ('31y378jx', 'abstract'),
#  ('36u8me7l', 'abstract'),
#  ('370fqkat', 'Discussion'),
#  ('38d6gb7o', 'Discussion'),
#  ('38f8ftmh', 'abstract'),
#  ('3aozpdr3', 'Discussion'),
#  ('3btc31kj', 'DISCUSSION'),
#  ('3btc31kj', 'abstract'),
#  ('3e6u4aza', 'abstract'),
#  ('3egv50vb', 'abstract'),
#  ('3khv6yrc', 'abstract'),
#  ('3pxc5wot', 'abstract'),
#  ('3pxc5wot', 'title'),
#  ('3wdzt391', 'Discussion'),
#  ('41jqgsv0', 'Conclusion'),
#  ('41jqgsv0', 'Discussion'),
#  ('41jqgsv0', 'title'),
#  ('48ul34xo', 'Discussion'),
#  ('4989atst', 'Discussion'),
#  ('4as055wh', 'Discussion'),
#  ('4fi0y96f', 'Discussion'),
#  ('4fz6iqwy', 'DISCUSSION'),
#  ('4gze6w35', 'abstract'),
#  ('4h930ksd', 'DISCUSSION'),
#  ('4ihv80au', 'Results and discussion'),
#  ('4lou2mb6', 'title'),
#  ('4lra2sih', 'abstract'),
#  ('4mv6qwpc', 'CONCLUSIONS'),
#  ('4pe9o59g', 'Conclusion'),
#  ('4pe9o59g', 'Discussion'),
#  ('4pe9o59g', 'Outcomes'),
#  ('4pe9o59g', 'abstract'),
#  ('4pe9o59g', 'title'),
#  ('4q50tw3d', 'Conclusions'),
#  ('4q50tw3d', 'abstract'),
#  ('4q50tw3d', 'title'),
#  ('4vfnjlr9', 'abstract'),
#  ('4vfnjlr9', 'title'),
#  ('4yuw7jo3', 'Discussion'),
#  ('510gmyb4',
#   'Therapeutic implications: tocilizumab & the risk of hasty conclusions'),
#  ('51b7hss1', 'Discussion'),
#  ('5367d55r', 'Conclusions'),
#  ('5367d55r', 'Discussion'),
#  ('5367d55r', 'abstract'),
#  ('54o2p36a', 'Discussion'),
#  ('566pbuic', 'Discussion'),
#  ('581tchjw', 'abstract'),
#  ('5ciaonf0', 'Discussion'),
#  ('5ciaonf0', 'abstract'),
#  ('5f95gve3', 'Results and Discussion'),
#  ('5f95gve3', 'abstract'),
#  ('5ig907on', 'title'),
#  ('5imbomop', 'Discussion'),
#  ('5l6c0it4', 'abstract'),
#  ('5o9bbspc', 'Discussion'),
#  ('5o9bbspc', 'abstract'),
#  ('5o9bbspc', 'title'),
#  ('5pfusktn', 'Discussion'),
#  ('5qbsmyjb', 'abstract'),
#  ('5trqi9tp', 'abstract'),
#  ('5trqi9tp', 'title'),
#  ('61snvddh', 'Discussion'),
#  ('647zcjgu', 'Discussion'),
#  ('647zcjgu', 'abstract'),
#  ('662pfa61', 'Results and Discussion'),
#  ('662pfa61', 'abstract'),
#  ('679qfp2s', 'Discussion'),
#  ('679qfp2s', 'abstract'),
#  ('679qfp2s', 'title'),
#  ('68193u0a', 'Discussion'),
#  ('68sbqdi3', 'Conclusion and future prospects'),
#  ('6agqpt2g', 'abstract'),
#  ('6agqpt2g', 'title'),
#  ('6ct748ek', 'Discussion'),
#  ('6g34qwer', 'Discussion'),
#  ('6ghu34m1', 'Discussion and conclusion.'),
#  ('6l5eraql', 'title'),
#  ('6nd9fmz3', 'DISCUSSION'),
#  ('6ojmmmuj', 'Discussion:'),
#  ('6om1y33o', 'abstract'),
#  ('6uaj8fb7', 'abstract'),
#  ('6wolrfvk', 'Discussion'),
#  ('6yinwbfh', 'abstract'),
#  ('6zk0ioep', '3) Discussion'),
#  ('6zk0ioep', 'abstract'),
#  ('73b58lcm', 'abstract'),
#  ('73gxq2w6', 'Discussion'),
#  ('73gxq2w6', 'abstract'),
#  ('769aw2iv', 'abstract'),
#  ('77ku0164', 'abstract'),
#  ('78qyuk5x', 'abstract'),
#  ('7dckgg6b', '4. Discussion'),
#  ('7e8zlt3t', 'abstract'),
#  ('7e8zlt3t', 'title'),
#  ('7joyaz7q', 'abstract'),
#  ('7k36owrf', 'abstract'),
#  ('7kxtntj2', 'Discussion'),
#  ('7kxtntj2', 'abstract'),
#  ('7t41wvw3', 'abstract'),
#  ('7v7pzclb', 'abstract'),
#  ('7vrm081c', 'Discussion'),
#  ('7z7zxcm2', 'Discussion ::: Results'),
#  ('80dfqjql', 'Conclusions'),
#  ('80dfqjql', 'Discussion'),
#  ('82qvdjju', 'abstract'),
#  ('84dsvygh', 'abstract'),
#  ('88xd6pi2', 'title'),
#  ('89sg0cpk', 'Discussion'),
#  ('8caqxfxv', 'abstract'),
#  ('8caqxfxv', 'title'),
#  ('8cg5yj20', 'Discussion'),
#  ('8eh90ber', 'abstract'),
#  ('8g6julo6', 'Clinical course and outcomes ::: RESULTS'),
#  ('8g6julo6', 'DISCUSSION'),
#  ('8gncbgot', '4.3. Therapeutics ::: 4. Discussion'),
#  ('8jhwamfv', 'abstract'),
#  ('8jhwamfv', 'title'),
#  ('8n3q30hy', 'Discussion'),
#  ('8nl1gywe', 'Discussion'),
#  ('8o6yjxwe', 'abstract'),
#  ('8orcmz32', 'abstract'),
#  ('8prn86g6', 'Results and Discussion'),
#  ('8prn86g6', 'abstract'),
#  ('8q1veo3q', 'Discussion'),
#  ('8q1veo3q', 'abstract'),
#  ('8ruux4sw', 'abstract'),
#  ('8xck5832', 'abstract'),
#  ('8xuwaban', 'abstract'),
#  ('8znnq0rh', 'Discussion'),
#  ('8znnq0rh', 'abstract'),
#  ('8znnq0rh', 'title'),
#  ('95fc828i', 'Conclusions'),
#  ('95fc828i', 'abstract'),
#  ('95fc828i', 'title'),
#  ('96v185b2', 'Discussion'),
#  ('97gawzw4', 'Conclusion:'),
#  ('97gawzw4', 'abstract'),
#  ('9ecuca17', 'Discussion'),
#  ('9ecuca17', 'abstract'),
#  ('9hh17k86', 'Discussion'),
#  ('9hknw4ws', 'Efficacy outcomes'),
#  ('9hknw4ws', 'Safety outcomes'),
#  ('9hknw4ws', 'abstract'),
#  ('9hknw4ws', 'title'),
#  ('9hxihlw9', 'Conclusions'),
#  ('9hxihlw9', 'title'),
#  ('9igk3ke1', 'abstract'),
#  ('9ih0ijqd', 'abstract'),
#  ('9il7coyk', 'Concluding Remarks'),
#  ('9j4ese89', 'Discussion'),
#  ('9j4ese89', 'abstract'),
#  ('9jatvium', 'Discussion'),
#  ('9jnixy2b', 'CONCLUSION'),
#  ('9jnixy2b', 'abstract'),
#  ('9lissxsy', 'Discussion'),
#  ('9lissxsy', 'Treatment Situation and In-hospital Outcomes'),
#  ('9q3lmsd3', 'title'),
#  ('9ryu9ady', 'Discussion'),
#  ('9vrny92m', 'Conclusions'),
#  ('a1pa6g5c', 'Discussion'),
#  ('a66sszp2', 'DISCUSSION'),
#  ('a66sszp2', 'abstract'),
#  ('a70k298w', 'Discussion'),
#  ('abgti7jh', 'Conclusions'),
#  ('aem47odf', 'title'),
#  ('ahxnhutv', 'Discussion'),
#  ('ahxnhutv', 'abstract'),
#  ('ajbypz7g', 'Discussion and conclusion'),
#  ('ajurlkwr', 'Discussion'),
#  ('ajurlkwr', 'abstract'),
#  ('ajurlkwr', 'title'),
#  ('amhj8ljl', 'abstract'),
#  ('amhj8ljl', 'title'),
#  ('aosmo568', 'abstract'),
#  ('aosmo568', 'title'),
#  ('arivuags', 'abstract'),
#  ('asivq33u', 'abstract'),
#  ('awbcw3gq', 'Results and Discussion'),
#  ('awbcw3gq', 'abstract'),
#  ('awbcw3gq', 'title'),
#  ('ayi928ct', 'Discussion'),
#  ('azvbl4ie', 'abstract'),
#  ('azvbl4ie', 'title'),
#  ('b31ctbat', 'Discussion'),
#  ('b31ctbat', 'abstract'),
#  ('b3ui95vx', 'Conclusion'),
#  ('b3ui95vx', 'title'),
#  ('b3y9zxjr', 'title'),
#  ('b4mdiont', 'Discussion'),
#  ('b4mdiont', 'abstract'),
#  ('b518n9dx', 'Conclusion'),
#  ('b518n9dx', 'abstract'),
#  ('ba6v30jg', 'Clinical features and outcomes of the patients'),
#  ('beoseizn', 'Discussion'),
#  ('bep0xtxa', 'Discussion'),
#  ('bg0cw5s6', 'abstract'),
#  ('bg0cw5s6', 'title'),
#  ('bieqiu8q', 'abstract'),
#  ('bjykd232', 'abstract'),
#  ('bjykd232', 'title'),
#  ('bkrg9qoy', 'Discussion:'),
#  ('bntjg90x', 'Discussion'),
#  ('bntjg90x', 'Maternal outcomes'),
#  ('bntjg90x', 'abstract'),
#  ('bqbxjofk', 'title'),
#  ('bsddxgx2', 'Discussion'),
#  ('bsddxgx2', 'abstract'),
#  ('buzj06i6', 'Discussion'),
#  ('buzj06i6', 'abstract'),
#  ('buzj06i6', 'title'),
#  ('bw9lbzvt', 'abstract'),
#  ('c08ptb1o', 'Results and Discussion'),
#  ('c8zfz8qt', 'DISCUSSION'),
#  ('cpu3q9o6', 'title'),
#  ('cqlg8go7', 'abstract'),
#  ('cs8n5kid', 'abstract'),
#  ('cszqykpu', 'Conclusion'),
#  ('cszqykpu', 'Results and Discussion'),
#  ('cszqykpu', 'abstract'),
#  ('cw76d00e', 'abstract'),
#  ('d1j95rqt', 'Discussion'),
#  ('d3q0xel1', 'Discussion'),
#  ('d7n1zy0b', 'Conclusion'),
#  ('d7stppv5', 'Discussion'),
#  ('d7stppv5',
#   'Figure 5. Predictors of SARS CoV-2 treatment outcomes with remdesivir.'),
#  ('d7stppv5',
#   'Projections of SARS CoV-2 outcomes assuming remdesivir treatment during early and late symptomatic phases'),
#  ('d7stppv5', 'abstract'),
#  ('da61tfr9', 'Conclusion'),
#  ('da61tfr9', 'title'),
#  ('dc8z4jzo', 'abstract'),
#  ('dc8z4jzo', 'title'),
#  ('dcf6bl8f', 'Abstract'),
#  ('dhy80rkn', 'Results and Discussions'),
#  ('di7hfghi', 'Discussion'),
#  ('di7hfghi', 'Outcomes'),
#  ('dl6rbqxp', 'abstract'),
#  ('dll2zv8s', 'abstract'),
#  ('dm98zekh', 'title'),
#  ('dmrtsxik', 'abstract'),
#  ('dmt5j061', 'abstract'),
#  ('dmud2zf7', 'Discussion'),
#  ('dmud2zf7', 'abstract'),
#  ('dpcpg5c1', 'abstract'),
#  ('dqour5jr', 'Discussion'),
#  ('dqxfcwyu', 'abstract'),
#  ('dtuk7gfv', 'title'),
#  ('dvpqkmnh', 'Discussion'),
#  ('dxabs45r', 'On the Interpretation of PIPE-Sites Predictions'),
#  ('dxs8ggyh', 'abstract'),
#  ('dxuabscn', 'abstract'),
#  ('e8qubwha', 'Results and Discussion'),
#  ('e8qubwha', 'abstract'),
#  ('e99athff', 'title'),
#  ('ebbzx8yr', 'abstract'),
#  ('egy8rgtl', 'DISCUSSION'),
#  ('enzfpvlx', 'abstract'),
#  ('et1ekgdl', 'abstract'),
#  ('et1ekgdl', 'title'),
#  ('eu3rry7p', 'Discussion'),
#  ('ezpjdz55', 'Discussion'),
#  ('ezpjdz55', 'abstract'),
#  ('f03ka7bd', 'abstract'),
#  ('f13iyvh6', 'Discussion'),
#  ('f13iyvh6', 'abstract'),
#  ('f13iyvh6', 'title'),
#  ('f16kh97s', 'abstract'),
#  ('f16kh97s', 'title'),
#  ('f3indt3b', 'Discussion'),
#  ('f3indt3b', 'abstract'),
#  ('f6muhf3d', 'Discussion'),
#  ('f6muhf3d', 'abstract'),
#  ('f6muhf3d', 'title'),
#  ('f99nd3dx', 'title'),
#  ('f9hyntvf', 'Discussion'),
#  ('f9hyntvf', 'abstract'),
#  ('fckn8ld4', 'abstract'),
#  ('fckn8ld4', 'title'),
#  ('fcmzdcuh', 'Discussion'),
#  ('fcmzdcuh', 'abstract'),
#  ('fdh54pqu', 'Discussion'),
#  ('fhy2z49t', 'abstract'),
#  ('fhy2z49t', 'title'),
#  ('fjmchbew', 'title'),
#  ('fk2wc715', 'Discussion'),
#  ('fn7l93wh', 'Conclusion'),
#  ('fnguelau', 'DISCUSSION'),
#  ('fnrm6a79', 'Discussion'),
#  ('fp9q8ayj', 'Discussion:'),
#  ('fp9q8ayj', 'abstract'),
#  ('fs0j5deg', 'title'),
#  ('fx51mtkh', 'abstract'),
#  ('fx7bkv8p', 'Conclusion'),
#  ('fx7bkv8p', 'Discussion'),
#  ('fx7bkv8p', 'abstract'),
#  ('g70y02rk', 'Discussion'),
#  ('g70y02rk', 'abstract'),
#  ('gag50cmf', 'Discussion'),
#  ('gag50cmf', 'Treatment and outcomes of the study population'),
#  ('geb4esu5', 'abstract'),
#  ('geb4esu5', 'title'),
#  ('gfjpsduv', 'abstract'),
#  ('ghfrwccu',
#   'The efficacy outcome ::: MSC treatment procedure and general patient information ::: RESULTS'),
#  ('gi1ujgwp', 'title'),
#  ('gi2y4jrn', 'abstract'),
#  ('gizxnw4n', 'abstract'),
#  ('gk1t1dor', 'Results and discussion'),
#  ('gk1t1dor', 'abstract'),
#  ('glfxrla9', 'abstract'),
#  ('glq0lckz', 'Conclusions'),
#  ('glq0lckz', 'Discussion'),
#  ('glq0lckz', 'Main Interventions and Outcomes'),
#  ('glq0lckz', 'abstract'),
#  ('gpr86lxe', 'abstract'),
#  ('gs0apie5', 'abstract'),
#  ('gzc72bdy', 'Discussion'),
#  ('gzc72bdy', 'abstract'),
#  ('h3mdrikn', 'Conclusion'),
#  ('h3mdrikn', 'Discussion'),
#  ('h3mdrikn', 'abstract'),
#  ('h3mdrikn', 'title'),
#  ('h4cu63cm', 'Discussion'),
#  ('h4cu63cm', 'Primary Outcome ::: Results'),
#  ('h4cu63cm', 'Secondary Outcomes ::: Results'),
#  ('h4cu63cm', 'abstract'),
#  ('h4cu63cm', 'title'),
#  ('h9hjslvb', 'abstract'),
#  ('h9vtq4pd', 'DISCUSSION'),
#  ('hc0za6fh', 'Discussion'),
#  ('hc0za6fh', 'abstract'),
#  ('hidirfkv', 'Discussion'),
#  ('hj675z1b', 'abstract'),
#  ('hmpmm9k8', 'abstract'),
#  ('hmqx925r', 'Abstract'),
#  ('hmqx925r', 'abstract'),
#  ('hmqx925r', 'title'),
#  ('hnoovm03', 'abstract'),
#  ('hq5um68k', 'abstract'),
#  ('hrntvohh', 'abstract'),
#  ('hsxwz798', 'Discussion'),
#  ('i0vxixf3', 'abstract'),
#  ('i1q3n101', 'Discussion'),
#  ('i3b647wv', 'Conclusion'),
#  ('i3b647wv', 'abstract'),
#  ('i4ijuk36', 'Conclusions and perspective.'),
#  ('i4ijuk36', 'Results and Discussion'),
#  ('i4ijuk36', 'abstract'),
#  ('i4ijuk36', 'title'),
#  ('i6pv90s9',
#   'What treatments are effective (including the role of antivirals and steroids)? ::: DISCUSSION'),
#  ('i6sdl2q2', 'DISCUSSION'),
#  ('if9lar1c', 'abstract'),
#  ('ifxm3j4y', 'Discussion'),
#  ('ifxm3j4y', 'Research in context Evidence before this study'),
#  ('igfur3l9', 'abstract'),
#  ('imkeghfd', 'abstract'),
#  ('iprkszdn', 'abstract'),
#  ('iqbetri6', 'Discussion'),
#  ('isbq1fqt', 'abstract'),
#  ('iu2ziccm', 'Discussion'),
#  ('ivy95jpw', 'title'),
#  ('j3avpu1y', 'abstract'),
#  ('j5bepvvw', 'abstract'),
#  ('j5kuxp0u', 'abstract'),
#  ('j6ihxzm2', 'Discussion'),
#  ('j8odxs1h', 'Discussion'),
#  ('j90jc0rj', 'Conclusion'),
#  ('j90jc0rj', 'Discussion'),
#  ('j90jc0rj', 'abstract'),
#  ('j9525ohh', 'Discussion'),
#  ('j9armxm9', 'abstract'),
#  ('jb4nxjnp', 'title'),
#  ('jbc74lcu', 'Discussion'),
#  ('jc9ugexn', 'Conclusion:'),
#  ('jc9ugexn', 'Discussion:'),
#  ('jc9ugexn', 'abstract'),
#  ('jc9ugexn', 'title'),
#  ('jg6v644y',
#   'Main management strategies, comorbid conditions, and clinical outcome data'),
#  ('jir7n19b', 'Discussion'),
#  ('jl48e5c0', 'abstract'),
#  ('jtsxpjhc', 'DISCUSSION'),
#  ('ju2en6n0', 'abstract'),
#  ('ju35nyir', 'Conclusions and Future Directions'),
#  ('juz9jnfk', 'abstract'),
#  ('jwivka1t', 'title'),
#  ('jx3alip6', 'abstract'),
#  ('k36rymkv', 'Discussion'),
#  ('k36rymkv', 'Research in context'),
#  ('k3y8tpps', 'DISCUSSION'),
#  ('k5y1qc82', 'Discussion'),
#  ('k65501xp', 'DISCUSSION'),
#  ('k86ljbxu', 'Discussion'),
#  ('k9xhphpl', 'Conclusions'),
#  ('k9xhphpl', 'Discussion'),
#  ('kbd2h4l0', 'abstract'),
#  ('kl9huu33', 'abstract'),
#  ('kqmlw4on', 'abstract'),
#  ('ksbha7kz', 'Discussion'),
#  ('ksbha7kz', 'abstract'),
#  ('l4xexlqi', 'Discussion'),
#  ('l9vtsj3e', 'abstract'),
#  ('ldf7uso2', 'Discussion'),
#  ('lg45goe2', 'abstract'),
#  ('lhd0jn0z', 'CONCLUSIONS'),
#  ('ljzmei78', 'abstract'),
#  ('lplodn60', 'Discussion'),
#  ('lujxql3a', 'Discussion'),
#  ('lzda8kyn', 'abstract'),
#  ('m0hivi0u', 'abstract'),
#  ('m0q7rm6z', 'Discussion:'),
#  ('m0q7rm6z', 'abstract'),
#  ('m40kwgcg', 'Discussion'),
#  ('m5k28kbu', 'abstract'),
#  ('m7dwbheg', 'abstract'),
#  ('m9f1j70w', 'abstract'),
#  ('mdectng8', 'abstract'),
#  ('mf0lgrlp', 'title'),
#  ('mmlbolwo', 'Abstract'),
#  ('mp3a9c9u', 'Discussion'),
#  ('mrgw2mnx', 'abstract'),
#  ('ms8sb929', 'abstract'),
#  ('mwttkclk', 'Discussion'),
#  ('mwttkclk', 'abstract'),
#  ('n1e3tfw4', 'abstract'),
#  ('n2tckfjq', 'abstract'),
#  ('n2tckfjq', 'title'),
#  ('n5gykapg', 'abstract'),
#  ('n6l2804j', 'Discussion 193'),
#  ('n6sq2jz9', 'Discussion'),
#  ('na8odvj7', 'Discussion'),
#  ('nadcsiii', 'DISCUSSION'),
#  ('nadcsiii', 'abstract'),
#  ('nc6tqv9v', 'abstract'),
#  ('nc6tqv9v', 'title'),
#  ('ndn6iwre', 'abstract'),
#  ('nhq0oq8y', 'Discussion'),
#  ('nlavfnpt', 'Discussion'),
#  ('nlsna66a', 'title'),
#  ('nr6ef5v1', 'abstract'),
#  ('nr6ef5v1', 'title'),
#  ('nxfr24sp', 'DISCUSSION'),
#  ('o0ot59di', 'abstract'),
#  ('o0ot59di', 'title'),
#  ('oam77j3m', 'abstract'),
#  ('ocomp998', 'abstract'),
#  ('oda2472v', 'title'),
#  ('ofoqk100', 'Treatment and clinical outcome'),
#  ('ol0bj3hs', 'abstract'),
#  ('ooj9yqbx', 'Conclusion'),
#  ('oqo8pa1p', 'abstract'),
#  ('otp1atui', 'title'),
#  ('ouca1bol', 'Discussion'),
#  ('owjgs6ja', 'abstract'),
#  ('owjgs6ja', 'title'),
#  ('p0b4mhif', 'abstract'),
#  ('p0b4mhif', 'title'),
#  ('p1w3p80y', 'abstract'),
#  ('p3g9nyl6', 'abstract'),
#  ('p4q64ksa', 'Conclusion'),
#  ('p4q64ksa', 'Results and Discussion'),
#  ('p4q64ksa', 'abstract'),
#  ('p5ecpcll', 'abstract'),
#  ('p91hfogv', 'title'),
#  ('pb16xxcm', 'Discussion'),
#  ('pb16xxcm', 'abstract'),
#  ('pgxew3yk', 'abstract'),
#  ('pjcg8c7i', 'Results and Discussion'),
#  ('pjcg8c7i', 'abstract'),
#  ('plede1kn', 'abstract'),
#  ('plpwjj4s', 'Conclusions'),
#  ('plpwjj4s', 'abstract'),
#  ('plpwjj4s', 'title'),
#  ('pmqqemku', 'Discussion'),
#  ('pmqqemku', 'Treatment and outcomes'),
#  ('pth2d40p', 'Conclusions'),
#  ('ptnmtvzj', 'CONCLUSIONS'),
#  ('ptnmtvzj', 'DISCUSSION'),
#  ('ptnmtvzj', 'abstract'),
#  ('pu6wni0e', 'CONCLUSIONS'),
#  ('pu6wni0e', 'abstract'),
#  ('pwumjw7a', 'abstract'),
#  ('q0yqnlyl', 'Conclusions'),
#  ('q0yqnlyl', 'Results and discussion'),
#  ('q0yqnlyl', 'abstract'),
#  ('q0yqnlyl', 'title'),
#  ('q8l3ra55', 'Conclusion'),
#  ('q8l3ra55', 'abstract'),
#  ('q8l3ra55', 'title'),
#  ('q8yh2zvv', 'DISCUSSION'),
#  ('qdamvwxl', 'DISCUSSION'),
#  ('qdt90c22', 'Discussion'),
#  ('qdt90c22', 'abstract'),
#  ('qebbkr6d', 'Discussion'),
#  ('qhbzs9tb', 'Discussion:'),
#  ('qmg58cgr', 'abstract'),
#  ('qmxgxz31', 'title'),
#  ('qopcs6jy', 'abstract'),
#  ('qq22z25y', 'Discussion'),
#  ('qr1rk9tr', 'Discussion'),
#  ('qtcqaqsi', 'abstract'),
#  ('qubmr10h', 'DISCUSSION'),
#  ('qvz63m93', 'Discussion'),
#  ('qxl14j2m', 'abstract'),
#  ('qymlefgi', 'abstract'),
#  ('r0r1kvkp', 'abstract'),
#  ('r1gpag26', 'abstract'),
#  ('r22x7gnu', 'title'),
#  ('r5jz7966', 'abstract'),
#  ('r88hpbxp', 'Discussion 230'),
#  ('r8ghn9z0', 'Discussion'),
#  ('re8fstqw', 'abstract'),
#  ('re8fstqw', 'title'),
#  ('rl3801n6', '11. Conclusion'),
#  ('rl3801n6', 'abstract'),
#  ('rosquj04', 'Discussion'),
#  ('rw37biop', 'abstract'),
#  ('s2j4qf0j', 'title'),
#  ('s3p14wnd', 'Discussion.'),
#  ('s4dqx9en', 'Discussion'),
#  ('s5215641', 'abstract'),
#  ('s73hljz9', 'Discussion'),
#  ('scc9wee0', 'Discussion'),
#  ('sdij1d90', 'abstract'),
#  ('sdij1d90', 'title'),
#  ('sdiwnhs0', 'Discussion'),
#  ('shl8s7lt', 'Discussion'),
#  ('skknfc6h', 'abstract'),
#  ('smfve2ur', 'Discussion'),
#  ('smvcbgeg', 'abstract'),
#  ('snp8o9fw', 'Discussion: Implications for COVID-19'),
#  ('sty7myg4', 'Discussion'),
#  ('suhqgmlo', 'Discussion'),
#  ('svvfeaxs', 'Discussion'),
#  ('svvfeaxs', 'abstract'),
#  ('svvfeaxs', 'title'),
#  ('t11611es', 'DISCUSSION'),
#  ('t159ctrv', 'title'),
#  ('t1n4fbsi', 'abstract'),
#  ('t1wpujpm', 'DISCUSSION'),
#  ('t1wpujpm', 'abstract'),
#  ('t996fbad', 'abstract'),
#  ('t9f87kk0', 'abstract'),
#  ('tbo6fkck', 'title'),
#  ('tdlcb9bf', 'Discussion'),
#  ('tdlcb9bf', 'title'),
#  ('tedurmyb', 'abstract'),
#  ('tedurmyb', 'title'),
#  ('tfb1ve2p', 'Discussion'),
#  ('tg8kfiot', 'abstract'),
#  ('tg8kfiot', 'title'),
#  ('tj21zcod', 'abstract'),
#  ('tllj77up', 'abstract'),
#  ('tmp6yxlv', 'abstract'),
#  ('tpp40j0g', 'abstract'),
#  ('tq9kjozt', 'Discussion'),
#  ('tq9kjozt', 'abstract'),
#  ('trlni6iq', 'DISCUSSION'),
#  ('ts2tsua7', 'Discussion'),
#  ('ts2tsua7', 'abstract'),
#  ('ttdzvw1s', 'Discussion'),
#  ('ttdzvw1s', 'abstract'),
#  ('tug2t7dm', 'Interpretation and Concluding Remarks'),
#  ('tuhesrpb', 'abstract'),
#  ('tv9xsned', 'Discussion'),
#  ('txuthqgo', 'Discussion.'),
#  ('txuthqgo', 'abstract'),
#  ('txuthqgo', 'title'),
#  ('txyf05n4', 'abstract'),
#  ('tyhwtt7j', 'Discussion'),
#  ('tylwbnpl', 'abstract'),
#  ('u1fmf4pg', 'Discussion'),
#  ('u3gmpklc', 'Discussion'),
#  ('u4di2tk7', 'abstract'),
#  ('u4di2tk7', 'title'),
#  ('u4taazr3', 'title'),
#  ('u5z8zji3', 'Discussion'),
#  ('u5z8zji3', 'abstract'),
#  ('u7zxlgxz', 'Conclusions'),
#  ('u8i3kbl4', 'abstract'),
#  ('ua6aeg5a', 'Discussion'),
#  ('uc3slu8q', 'Discussion'),
#  ('uc3slu8q', 'abstract'),
#  ('ud6tuchk', 'DISCUSSION'),
#  ('uizdigo0', 'abstract'),
#  ('ujk48pe7', 'abstract'),
#  ('uqq27wyq', 'abstract'),
#  ('urr5iuy2', 'abstract'),
#  ('uwj62cuv', 'Discussion'),
#  ('uza4orb8', 'Conclusion'),
#  ('v0ln3wfa', 'abstract'),
#  ('vbayngh0', 'DISCUSSION'),
#  ('vbgf50os', 'abstract'),
#  ('vbgf50os', 'title'),
#  ('ver7x3lx', 'abstract'),
#  ('vg1vvm6f', 'Discussion'),
#  ('vh9wreex', 'Conclusion'),
#  ('vh9wreex', 'abstract'),
#  ('vhh9y3je', 'Discussion'),
#  ('vhh9y3je', 'abstract'),
#  ('vijzfbyj', 'abstract'),
#  ('vkj9kjwx', 'abstract'),
#  ('vm0k7hfx', 'abstract'),
#  ('vm0k7hfx', 'title'),
#  ('vorczspu', 'abstract'),
#  ('vpodtbjk', 'abstract'),
#  ('vwu27sw2', 'Discussion'),
#  ('vxqdfiel', 'RESULTS AND DISCUSSION'),
#  ('vxqdfiel', 'abstract'),
#  ('vyayyk50', 'abstract'),
#  ('vyue7kc0', 'title'),
#  ('w02fqtci', 'Discussion'),
#  ('w02fqtci', 'abstract'),
#  ('w02mylsc', 'Conclusions'),
#  ('w02mylsc', 'Discussion'),
#  ('w02mylsc', 'abstract'),
#  ('w3fsxg90', 'DISCUSSION'),
#  ('w3fsxg90',
#   'Risk factors associated with clinical outcomes and survival analysis'),
#  ('w49i0xkz', 'Conclusions and Future Directions'),
#  ('w5zxzpj7', 'abstract'),
#  ('w5zxzpj7', 'title'),
#  ('w7lb94pb', 'Case presentation and discussion'),
#  ('wh3btcd4', 'abstract'),
#  ('whnw19pc', 'abstract'),
#  ('wmfcwqfw', 'abstract'),
#  ('wmfcwqfw', 'title'),
#  ('wnu6nvtu', 'Discussion'),
#  ('wnu6nvtu', 'abstract'),
#  ('wnu6nvtu', 'title'),
#  ('wta7ndnk', 'abstract'),
#  ('wtvjjc7p', 'DISCUSSION 272'),
#  ('wuclekt6', 'abstract'),
#  ('wx0nhx8i', 'Discussion'),
#  ('wxagjqbt', 'Discussion'),
#  ('wynyrumi', 'Discussion'),
#  ('x23ej29m', 'Discussion'),
#  ('x2gxgave', 'abstract'),
#  ('x2gxgave', 'title'),
#  ('x32egf2t', 'Discussion'),
#  ('x3c7zjvg', 'Discussion'),
#  ('x3c7zjvg', 'abstract'),
#  ('x3n6uj21', 'Abstract'),
#  ('x50tvq3a', 'Discussion'),
#  ('x50tvq3a', 'abstract'),
#  ('x50tvq3a', 'title'),
#  ('x5btuxrq', 'DISCUSSION'),
#  ('x8jgcqts', 'Conclusion'),
#  ('x8jgcqts', 'Results and Discussion'),
#  ('x8jgcqts', 'abstract'),
#  ('x8tcmtpj', 'abstract'),
#  ('xa6kwguo', 'abstract'),
#  ('xbjn879m', 'abstract'),
#  ('xbjn879m', 'title'),
#  ('xdh86nh5', 'abstract'),
#  ('xetzg7gp', 'abstract'),
#  ('xhachzby', 'Results and Discussion'),
#  ('xieqswct', 'DISCUSSION AND PERSPECTIVES'),
#  ('xiynfpuw', 'DISCUSSION'),
#  ('xle4bx49', 'Discussion'),
#  ('xo5u02d7', 'abstract'),
#  ('xtmozkf6', 'Discussion'),
#  ('xv3413k1', 'abstract'),
#  ('xvba5mqq', 'Discussion'),
#  ('xvba5mqq', 'abstract'),
#  ('xvfl7ycj', 'abstract'),
#  ('xwmr7up9', 'Discussion'),
#  ('xwmr7up9', 'abstract'),
#  ('y29kct7v', 'Conclusion'),
#  ('y7lrp0gc', 'title'),
#  ('yd7tu7u4', 'abstract'),
#  ('yi1s6xap', 'Discussion'),
#  ('ym44s4oc', 'Discussion'),
#  ('ym73y41t', 'Discussion'),
#  ('ymc93p0w', 'Results and Discussion'),
#  ('ymc93p0w', 'abstract'),
#  ('ymc93p0w', 'title'),
#  ('ymdi0sed', 'Conclusion'),
#  ('ymdi0sed', 'abstract'),
#  ('yn8nzezq', 'abstract'),
#  ('yqiggzk9', 'abstract'),
#  ('ysbopqqq', 'Discussion'),
#  ('ysbopqqq', 'Treatment and outcomes'),
#  ('ysbopqqq', 'abstract'),
#  ('yvqk4woz', 'Discussion'),
#  ('yx8b2moc', 'abstract'),
#  ('yzrni12u', 'Results & Discussion'),
#  ('z0qzgu5m', 'abstract'),
#  ('z434n5k1', 'title'),
#  ('z7r4n0w7', 'abstract'),
#  ('za3qypgg', 'Conclusion ::: All cytotoxic chemotherapy ::: Results'),
#  ('za3qypgg', 'Conclusion ::: IL-1 blockade ::: Results'),
#  ('za3qypgg', 'Conclusion ::: IL-6 blockade ::: Results'),
#  ('za3qypgg', 'Conclusion ::: Low-dose steroids and NSAIDs ::: Results'),
#  ('za3qypgg', 'Conclusion ::: Tacrolimus ::: Results'),
#  ('za3qypgg', 'Overall conclusion'),
#  ('za3qypgg', 'abstract'),
#  ('zb434ve3', 'Discussion'),
#  ('zb434ve3', 'abstract'),
#  ('zblitbo0', 'Discussion:'),
#  ('zcjsvwso', 'abstract'),
#  ('zdog6ddu', 'abstract'),
#  ('zgdbvfi4', 'Conclusions'),
#  ('zgdbvfi4', 'Results and discussion'),
#  ('zgdbvfi4', 'abstract'),
#  ('zghh0zbd', 'abstract'),
#  ('zghh0zbd', 'title'),
#  ('ziepfnpz', 'abstract'),
#  ('zn87f1lk', 'title'),
#  ('zph6r4il', 'abstract'),
#  ('zwqci59h', 'Discussion'),
#  ('zzljrkbf', 'abstract')]

# %%
test_df.loc[test_df.cord_uid == '647zcjgu' ].loc[test_df.section == 'Discussion'].text.tolist()[0]
# Out:
# 'since its initial outbreak, the 2019-ncov infection is much more contagious than it was originally thought. we know that the virus is capable of spreading quickly from human to human and that people can spread the virus even before they become symptomatic [1] . this makes it harder to contain the virus, and many are concerned about the possibility of a new pandemic. our study suggests unique structural features of the spike glycoprotein rbd of 2019-ncov that confers potentially higher affinity binding for its receptor than found with sars-cov. with a higher affinity binding capability, the number of viruses required to infect a cell is much reduced. this partly explains why 2019-ncov appears to be more aggressive than sars-cov. this also reminds us of a lesser-known coronavirus hcov-nl63 that also uses ace2 also as a receptor. hcov-nl63 was initially isolated from a child with bronchiolitis in the netherlands [21] . it belongs to the alphacoronavirus subfamily. the rbd of sars-cov shares no structural homology with that of sars-cov but recognizes the same region in ace2. however, cocrystal structure reveals that rbd of nl63-cov has a narrower contact with ace2, involving fewer amino acids [22] . this presumably results in a weaker interaction. evidently, nl63-cov does not spread aggressively and only causes mild to moderate respiratory infections [23] . the exact mode of transmission for 2019-ncov has not been firmly established. sars-cov is thought to be transmitted by respiratory droplets produced when an infected person coughs or sneezes [19] . the respiratory droplets spread can occur only through direct person-to-person contact or at a close distance. presumably, 2019-ncov can be transmitted through respiratory droplets. it may also be transmitted more effectively through the air over a long distance (airborne spread) or by other ways. considering the predominant expression of ace2 in intestines and kidney, 2019-ncov may infect cells in these tissues and find its way into feces and urine. this makes transmission through the fecal-oral route and bodyfluids (urine) possible. the presence of 2019-ncov in feces supports such a notion [20] . specific rbd-receptor binding determines if a cell or animal can be infected and also serves as a target for therapeutic inventions to treat diseases caused by coronaviruses. by binding directly to ace2 on the surface of host cells, spike glycoprotein plays an essential role in virus infection. an obvious way to stop the virus infection is to block the rbd and ace2 interaction. this can be achieved by using antibodies or small molecular inhibitors. naturally, antibodies and inhibitors that can disrupt the interaction of rbd with ace2 is of therapeutic importance. by using a molecular docking approach, an earlier study identified n-(2-aminoethyl)-1 aziridineethanamine as a novel ace2 inhibitor that effectively blocks the sars-cov rbd-mediated cell fusion [24] . this has provided a potential candidate and lead compound for further therapeutic drug development. meanwhile, biochemical and cell-based assays can be established to screen chemical compound libraries to identify novel inhibitors. on the other hand, many ace inhibitors are currently used to treat hypertension and other cardiovascular diseases [25] . among them are captopril, perindopril, ramipril, lisinopril, benazepril, and moexipril. although these drugs primarily target ace, a homolog of ace2 with 42% sequence identity and 61% sequence similarity in the catalytic domain, they may be effective toward ace2 as well [26] . it should be noted that ace inhibitors bind to the catalytic center rather than rbd binding site. nonetheless, these enzymatic inhibitors may indirectly alter conformation of the rbd binding site and thereby affect the interaction of ace2 with rbd. it is certainly worthwhile to test these drugs for their ability to block the rbd/ace2 interaction.'

# %%
"""
Manual checking for drug mentions excluded by regex search, using direct string matches.

"""

sections_texts = concat_sent_df.sentence.tolist()

cord_uids_contain_drugs_manual_search_dict = {}

idx = 0
for idx, row in concat_sent_df.iterrows():
    text = row.sentence
    for drug in drug_terms:
        if drug in text:
            cord_uids_contain_drugs_manual_search_dict.setdefault(row.cord_uid, []).append(drug)
            
    idx +=1
    
cord_uids_with_manual_search_drugs = set(cord_uids_contain_drugs_manual_search_dict.keys())

#Difference in cord_uid lists
diff_cord_uids = cord_uids_with_manual_search_drugs - set(cord_uids_with_drugs)

# %%
diff_cord = 'ela022bo'

drugs_used = cord_uids_contain_drugs_manual_search_dict[diff_cord]
test_df = concat_sent_df.loc[concat_sent_df.cord_uid == diff_cord]

for sent in test_df.text.tolist():
    if 'lustra' in sent:
        print(sent)
# Out:
# the sars-cov-2 epidemic is one of the biggest challenges healthcare systems worldwide have ever had to face. to curb transmission many countries have adopted social distancing measures and travel restrictions. estimating the effect of these measures in each context is challenging and requires mathematical models of the transmission dynamics. projections for the future course of the epidemic strongly rely on model predictions and accurate representation of real-time data as they accumulate. here i develop an seir modeling framework for covid-19, to evaluate reported cases and fatalities, and to enable forecasting using evidence-based bayesian parameter estimation. this bayesian framework offers a tool to parametrize real-time dynamics of covid-19 cases, and explore the effect of control as it unfolds in any setting. i apply the model to covid-19 data from albania, where drastic control measures were put in place already on the day of the first confirmed case. evaluating the dynamics of reported cases 9-31 march 2020, i estimate parameters and make preliminary projections. three weeks into the measures, albanian data already indicate a strong signature of more than 40% transmission reduction, and lend support to a progressively increasing effect of control measures rather than a static one. in the albanian setting, the model and data match well, projecting the peak of the outbreak may be around 5-15 april, and be contained within 300 active confirmed cases if control continues with the same trend. this framework can be used to understand the quantitative effects of different control measures in real-time, and inform adaptive intervention for success in other settings. albania reported the first confirmed case of coronavirus disease (covid-19) on the 9th of march 2020. given very close travel connections with italy, where the epidemic grew very fast over the month of february, the concern over a major similar outbreak in albania was significant. immediately following the first case confirmation, country-wide measures were taken to drastically reduce transmission and contain the spread of infection. these included university and school closures, suspension of public gatherings, closure of bars and cafes, travel restrictions, and gradually a lockdown of the population. the parameters governing the epidemic course of covid-19 in albania remain unknown. the first week after the first detected case, official numbers indicated case counts amounting to a total 59 confirmed cases on march 18, with two fatalities (albanian institute of public health). the initial exponential growth rate of the number of cases in albania was r = 0.17 during the first week, coming from a doubling time of 4 days (1), but this has slowed down from march 14 onward. it is not known what will be the trajectory of the epidemic in this country. following the diagnosis of the first cases, the borders with italy, greece, kosovo were rapidly closed and many flights to other european destinations were limited or cancelled. the aim of this study is to provide a framework for interpreting and forecasting the real-time course of the epidemic as it unfolds in a given setting. i use the albanian data as an illustration for the application of the model. with the model and bayesian estimation, continuously-updating values for the parameters, underlying the epidemic course of covid-19, can be obtained, and continuously-updating projections. based on the model application to albania, the parameter estimates and their associated uncertainty, suggest clear positive effects of control measures and make precise quantitative projections about the magnitude and timing of the peak of this outbreak in albania.

# %%
test_df = concat_sent_df.loc[concat_sent_df.cord_uid == 'ela022bo']

for sent in test_df.sentence.tolist():
    if 'lustra' in sent:
        print(sent)
# Out:
# the sars-cov-2 epidemic is one of the biggest challenges healthcare systems worldwide have ever had to face. to curb transmission many countries have adopted social distancing measures and travel restrictions. estimating the effect of these measures in each context is challenging and requires mathematical models of the transmission dynamics. projections for the future course of the epidemic strongly rely on model predictions and accurate representation of real-time data as they accumulate. here i develop an seir modeling framework for covid-19, to evaluate reported cases and fatalities, and to enable forecasting using evidence-based bayesian parameter estimation. this bayesian framework offers a tool to parametrize real-time dynamics of covid-19 cases, and explore the effect of control as it unfolds in any setting. i apply the model to covid-19 data from albania, where drastic control measures were put in place already on the day of the first confirmed case. evaluating the dynamics of reported cases 9-31 march 2020, i estimate parameters and make preliminary projections. three weeks into the measures, albanian data already indicate a strong signature of more than 40% transmission reduction, and lend support to a progressively increasing effect of control measures rather than a static one. in the albanian setting, the model and data match well, projecting the peak of the outbreak may be around 5-15 april, and be contained within 300 active confirmed cases if control continues with the same trend. this framework can be used to understand the quantitative effects of different control measures in real-time, and inform adaptive intervention for success in other settings. albania reported the first confirmed case of coronavirus disease (covid-19) on the 9th of march 2020. given very close travel connections with italy, where the epidemic grew very fast over the month of february, the concern over a major similar outbreak in albania was significant. immediately following the first case confirmation, country-wide measures were taken to drastically reduce transmission and contain the spread of infection. these included university and school closures, suspension of public gatherings, closure of bars and cafes, travel restrictions, and gradually a lockdown of the population. the parameters governing the epidemic course of covid-19 in albania remain unknown. the first week after the first detected case, official numbers indicated case counts amounting to a total 59 confirmed cases on march 18, with two fatalities (albanian institute of public health). the initial exponential growth rate of the number of cases in albania was r = 0.17 during the first week, coming from a doubling time of 4 days (1), but this has slowed down from march 14 onward. it is not known what will be the trajectory of the epidemic in this country. following the diagnosis of the first cases, the borders with italy, greece, kosovo were rapidly closed and many flights to other european destinations were limited or cancelled. the aim of this study is to provide a framework for interpreting and forecasting the real-time course of the epidemic as it unfolds in a given setting. i use the albanian data as an illustration for the application of the model. with the model and bayesian estimation, continuously-updating values for the parameters, underlying the epidemic course of covid-19, can be obtained, and continuously-updating projections. based on the model application to albania, the parameter estimates and their associated uncertainty, suggest clear positive effects of control measures and make precise quantitative projections about the magnitude and timing of the peak of this outbreak in albania.

# %%
len(section_text_with_drugs_df.cord_uid.unique())
# Out:
# 544

# %%
concat_sent_df.loc[concat_sent_df.cord_uid == 'zph6r4il'].loc[concat_sent_df.section == 'abstract'].text.tolist()[0]
# Out:
# 'objective: the sars-cov-2-infected disease (covid-19) outbreak is a major threat to human beings. previous studies mainly focused on wuhan and typical symptoms. we analysed 74 confirmed covid-19 cases with gi symptoms in the zhejiang province to determine epidemiological, clinical and virological characteristics. design: covid-19 hospital patients were admitted in the zhejiang province from 17 january 2020 to 8 february 2020. epidemiological, demographic, clinical, laboratory, management and outcome data of patients with gi symptoms were analysed using multivariate analysis for risk of severe/critical type. bioinformatics were used to analyse features of sars-cov-2 from zhejiang province. results: among enrolled 651 patients, 74 (11.4%) presented with at least one gi symptom (nausea, vomiting or diarrhoea), average age of 46.14 years, 4-day incubation period and 10.8% had pre-existing liver disease. of patients with covid-19 with gi symptoms, 17 (22.97%) and 23 (31.08%) had severe/critical types and family clustering, respectively, significantly higher than those without gi symptoms, 47 (8.14%) and 118 (20.45%). of patients with covid-19 with gi symptoms, 29 (39.19%), 23 (31.08%), 8 (10.81%) and 16 (21.62%) had significantly higher rates of fever >38.5°c, fatigue, shortness of breath and headache, respectively. low-dose glucocorticoids and antibiotics were administered to 14.86% and 41.89% of patients, respectively. sputum production and increased lactate dehydrogenase/glucose levels were risk factors for severe/critical type. bioinformatics showed sequence mutation of sars-cov-2 with m(6)a methylation and changed binding capacity with ace2. conclusion: we report covid-19 cases with gi symptoms with novel features outside wuhan. attention to patients with covid-19 with non-classic symptoms should increase to protect health providers.'

# %%
section_text_with_drugs_ann_df
# Out:
#       cord_uid                    section  \
# 14    02q9y011     RESULTS AND DISCUSSION
# 56    08vsaov7                 DISCUSSION
# 66    0a49okho                 Discussion
# 82    0d77ojnb  Discussion and Conclusion
# 83    0d77ojnb                   abstract
# ...        ...                        ...
# 9828  ziepfnpz                   abstract
# 9872  zn87f1lk                      title
# 9893  zph6r4il                   abstract
# 9949  zwqci59h                 Discussion
# 9962  zzljrkbf                   abstract
#
#                                                    text  \
# 14    hypervariability in the nsp3 macro x domain-th...
# 56    the predominant pathological features of covid...
# 66    the term 'flatten the curve', originating from...
# 82    the rapid spread of sars-cov-2 represents a si...
# 83    [{'text': 'many pathogens take advantage of th...
# ...                                                 ...
# 9828  the epidemiological and clinical characteristi...
# 9872  hydroxychloroquine, a less toxic derivative of...
# 9893  objective: the sars-cov-2-infected disease (co...
# 9949  although recent studies have reported epidemio...
# 9962  objective to investigate the diagnostic value ...
#
#                                         drug_terms_used
# 14                 amino acids,glycine,protein c,tandem
# 56                                       angiotensin ii
# 66                                       stimate,tandem
# 82                    heparin,cosamin,heparin,protein s
# 83                              heparin,cosamin,heparin
# ...                                                 ...
# 9828                                         tacrolimus
# 9872         chloroquine,chloroquine,hydroxychloroquine
# 9893                                     lactate,ultiva
# 9949  compro,creatinine,cyclosporine,methylprednisol...
# 9962                                   immunoglobulin g
#
# [766 rows x 4 columns]

# %%
with open('../../../../resources/drug_terms_regex_pattern_200504.txt', 'w') as f:
    f.write(drug_terms_pattern)

# %%
section_text_df = pd.read_csv(section_text_with_drugs_ann_outpath)

# %%
section_text_df
# Out:
#      Unnamed: 0  cord_uid                    section  \
# 0            14  02q9y011     RESULTS AND DISCUSSION
# 1            21  03eifdr1                      title
# 2            56  08vsaov7                 DISCUSSION
# 3            66  0a49okho                 Discussion
# 4            82  0d77ojnb  Discussion and Conclusion
# ..          ...       ...                        ...
# 795        9828  ziepfnpz                   abstract
# 796        9872  zn87f1lk                      title
# 797        9893  zph6r4il                   abstract
# 798        9949  zwqci59h                 Discussion
# 799        9962  zzljrkbf                   abstract
#
#                                            text_spaced  \
# 0     hypervariability in the nsp3 macro x domain-t...
# 1     chloroquine as prophylactic agent against cov...
# 2     the predominant pathological features of covi...
# 3     the term 'flatten the curve', originating fro...
# 4     the rapid spread of sars-cov-2 represents a s...
# ..                                                 ...
# 795   the epidemiological and clinical characterist...
# 796   hydroxychloroquine, a less toxic derivative o...
# 797   objective: the sars-cov-2-infected disease (c...
# 798   although recent studies have reported epidemi...
# 799   objective to investigate the diagnostic value...
#
#                                        drug_terms_used
# 0                 amino acids,glycine,protein c,tandem
# 1                              chloroquine,chloroquine
# 2                                       angiotensin ii
# 3                                       stimate,tandem
# 4                    heparin,cosamin,heparin,protein s
# ..                                                 ...
# 795                                         tacrolimus
# 796         chloroquine,chloroquine,hydroxychloroquine
# 797                                     lactate,ultiva
# 798  compro,creatinine,cyclosporine,methylprednisol...
# 799                                   immunoglobulin g
#
# [800 rows x 5 columns]
